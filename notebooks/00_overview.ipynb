# %% [markdown]
# # Colocalization QTL Pipeline — Overview
#
# This notebook outlines a reproducible workflow for colocating GWAS signals with GTEx QTL data (bulk eQTL + sQTL).
#
# **Scope:**
# - Ingest GWAS summary stats
# - Download GTEx QTLs (bulk + splicing)
# - Harmonize variants
# - Run coloc per locus
